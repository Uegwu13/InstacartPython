# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating path
path = r'C:\Users\13472\Documents\05-2023 Instacart Basket Analysis- UE'

# %% [markdown]
# # User Define Function

# %%
# Define Function
def add_num(x,y):
   sum = x + y
   return sum

# %%
# Run Function
add_num (9,11)
# Out:
# 20

# %% [markdown]
# # Importing DF

# %%
# Importing orders_products_merged.pkl
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0.1  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    orders_hod  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           7                    15.0         196                  1
# 2          12                    21.0         196                  1
# 3           7                    29.0         196                  1
# 4          15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# 0          0         Soda        77              7     9.0   both
# ...

# %%
# Creating subset
df = df_ords_prods_merged[:1000000]

# %%
df.head()
# Out:
#    Unnamed: 0.1  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    orders_hod  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           7                    15.0         196                  1
# 2          12                    21.0         196                  1
# 3           7                    29.0         196                  1
# 4          15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# 0          0         Soda        77              7     9.0   both
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0.1  order_id  user_id  order_number  orders_day_of_week  \
# 999995       2731921   2836489   164627            14                   0
# 999996       2731962   1843600   164632             5                   1
# 999997       2731966    733106   164632             9                   2
# 999998       2731974   1650124   164632            17                   6
# 999999       2731979   3378258   164632            22                   6
#
#         orders_hod  days_since_prior_order  product_id  add_to_cart_order  \
# 999995          15                     6.0       30489                  2
# 999996          19                     9.0       30489                  2
# 999997          22                    10.0       30489                  3
# 999998          17                    13.0       30489                  1
# 999999          10                    15.0       30489                  3
#
#         reordered     product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# # If Statement

# %%
# Defining function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\13472\AppData\Local\Temp\ipykernel_5836\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If Statements with loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\13472\AppData\Local\Temp\ipykernel_5836\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Repeating proccess with merged df

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # IF- Statements for For- Loops

# %%
# Creating a "how busy each day is " column
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Creating empty list
result = []

# %%
for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Combining with dataframe
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task 4.7

# %%
# Step 2: Clients changed mind, create new column
result_1 = []

# %%
# Filling 'result_1' with busiest,least busy, or regularly busy
for x in df_ords_prods_merged["orders_day_of_week"]:
  if x == 0 or x == 1:
    result_1.append("Busiest")
  elif x == 3 or x == 4:
    result_1.append("Least busy")
  else:
    result_1.append("Regularly busy")

# %%
result_1
# Out:
# ['Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest',
#  'Busiest',
#  'Busiest',
#  'Least busy',
#  'Busiest',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest',
#  'Busiest',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Busiest',
#  'Busiest',
#  'Busiest',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest',
#  'Busiest',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest',
#  'Busiest',
#  'Regularly busy',
#  'Busiest',
#  'Busiest',
#  'Least busy',
#  'Regularly busy',
#  'Busiest',
#  'Busiest',
#  'Busiest',
#  'Busiest',
#  'Busiest',
#  'Regularly busy',
# ...

# %%
# Combining with dataframe
df_ords_prods_merged['busiest_days'] = result_1

# %% [markdown]
# # Step 3:Checking new column for accuracy

# %%
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest           11864412
# Least busy         7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
#  The two busiest days were 0 and 1 which adds up. As well as the 2 slowest days which were 3 and 4

# %% [markdown]
# # Step 4

# %%
# Create a new column containing these labels called “busiest_period_of_day.”
df_ords_prods_merged['orders_hod'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: orders_hod, dtype: int64

# %%
# Creating an empty list 
result_2 =[]

# %%
# Filling 'result_2' with Most orders, Fewest orders, or Average orders

for x in df_ords_prods_merged["orders_hod"]:
  if x in range(9,17):              # will stop at 16
    result_2.append("Most orders")
  elif (x in range(0,7)) or x == 23:
    result_2.append("Fewest orders")
  else:
    result_2.append("Average orders")

# %%
result_2
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Combining with dataframe
df_ords_prods_merged['busiest_period_of_day'] = result_2

# %% [markdown]
# # Step 5: Print the frequency for this new column

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # Step 7

# %%
# Exporting data
df_ords_prods_merged.to_pickle(os.path.join(path, '02. Data','Prepared Data', 'orders_prods_busy.pkl'))
